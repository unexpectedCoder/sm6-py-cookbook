# %% [markdown]
# # Особенности matplotlib
#
# В данном разделе рассмотрим некоторые особенности библиотеки [matplotlib](https://matplotlib.org/), наиболее часто применяемые на практике, на примере построения графика $y = x^3$ на отрезке $x \in [-2, 2]$.
#
# ```{note}
# Будем использовать объектно-ориентированный подход.
# ```

# %% [markdown]
# ## Данные для визуализации

# %%
import numpy as np

def func(x):
    return x**3

x = np.linspace(-2, 2, 101)
y = func(x)

# %% [markdown]
# ## Подписи графика и его осей, отображение сетки
#
# Отобразить названия осей можно с помощью методов `set_xlabel` и `set_ylabel` класса `plt.axis`.
# При этом действует математический синтаксис "\$...\$". Аналогичным способом пишется заголовок графика - метод `set_title`.
#
# Включить или отключить отбражение сетки можно с помощью метода `grid` того же класса `plt.axis`.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_xlabel("$x$")
ax.set_ylabel("Значение функции $y = x^3$")
ax.set_title("Пример графика $f(x)$")
ax.grid(True)

# %% [markdown]
# Можно настроить отображение и через единный метод `plt.axis.set`, передав ему соответствующие именованные аргументы:

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set(
    xlabel="$x$",
    ylabel="Значение функции $y = x^3$",
    title="Пример функции $f(x)$"
)
ax.grid(True)

# %% [markdown]
# ## Цвет линии, её стиль и другие параметры
#
# Сделаем линию утолщённой шриховой красной:

# %%
fig, ax = plt.subplots()
ax.plot(x, y, color="red", linestyle="--", linewidth=4)

# %% [markdown]
# То же самое можно записать в сокращённой форме:

# %%
fig, ax = plt.subplots()
ax.plot(x, y, c="r", ls="--", lw=4)

# %% [markdown]
# Или даже так:

# %%
fig, ax = plt.subplots()
ax.plot(x, y, "r--", lw=4)

# %% [markdown]
# Сделать график утолщённым точечным полупрозрачно-чёрным можно так:

# %%
fig, ax = plt.subplots()
ax.plot(x, y, "k:", lw=4, alpha=0.5)

# %% [markdown]
# ```{note}
# Краткое обозначение чёрного цвета `k` (key-color) связано с тем, что сокращение `b` занято синим цветом (blue).
# Если писать полное наименование цвета, то чёрный цвет, естественно, задаётся так `color="black"`.
# ```

# %% [markdown]
# ```{note}
# Вы можете задавать любой цвет шестнадцатиричным кодом вот так `c="#cd5c5c"`.
# ```

# %% [markdown]
# Многие именованные параметры линий работают и для линий сетки. Вот, например, чёрная сетка в точку:

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.grid(True, c="k", ls=":")

# %% [markdown]
# ## Пределы и масштабы осей
#
# `matplotlib` по умолчанию настраивает оси автоматически на основе входных данных. В большинстве случаев этого достаточно, но иногда возникает необходимость назначить пределы осей вручную, например, когда эти пределы должны быть одинаковы на разных графиках.
#
# Переназначить пределы осей можно через тот же метод `plt.axis.set` (или отдельные методы `set_xlim` и `set_ylim`):

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set(xlim=[-2, 3], ylim=[-2, 10])
# Out:
# [(-2.0, 3.0), (-2.0, 10.0)]

# %% [markdown]
# Можно заметить, что на всех ранее построенных графиках масштабы осей *x* и *y* неодинаковы.
# Это искажает пропорции графика, что в ряде случаев негативно сказывается на информативности графика.
# В качестве примера можно привести изображение траектории полёта летательного аппарата в вертикальной плоскости.
#
# Сделать масштаб осей одинаковым вручную может быть затруднительно, поскольку масштаб зависит от размеров окна, геометрической длины осей. Хорошо, что в `matplotlib` реализована возможность построения в одинаковом масштабе по осям: `plt.axis.set_aspect("equal")` или `set(aspect="equal")`. В таком случае геометрия линий не будет искажена.
# При этом, в интерактивном режиме растягивая окно графика, мы будем получать так же одинаковые масштабы осей.

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set(aspect="equal")
# Out:
# [None]

# %% [markdown]
# ## Построение двух графиков в одних осях. Легенда
#
# Построим в одном поле график всё той же функции $f(x) = x^3$, а также графики её производных $f'(x) = 3 x^2$ и $f''(x) = 6 x$.

# %%
def func_der(x):
    return 3 * x**2

def func_der2(x):
    return 6 * x

y_der = func_der(x)
y_der2 = func_der2(x)

# %% [markdown]
# Для этого просто ещё раз вызовем у оси `ax` метод `plot` с данными `x` и `y_der`. Заодно подпишем оси и отобразим сетку.

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.plot(x, y_der)
ax.plot(x, y_der2)
ax.set(
    xlabel="$x$",
    ylabel="$y$",
    title="Функция $f(x) = x^3$ и её производные"
)
ax.grid(True)

# %% [markdown]
# Но как показать, где конкретно график функции, а где график её производной?
# Для этого предназначена легенда (legend) графика: метод `plt.axis.legend`. Однако, чтобы легенда отобразила содержательную информацию, необходимо в каждом методе `plt.axis.plot` инициализировать поле `label` (метка, ярлык).
# Текст из `label` будет отображён на графике.
#
# ```{note}
# В тексте меток также возможно писать математические выражения `"\$...\$"`.
# ```

# %%
fig, ax = plt.subplots()
ax.plot(x, y, label="Функция $f(x)$")
ax.plot(x, y_der, label="Производная $f'(x)$")
ax.plot(x, y_der2, label="Производная $f''(x)$")
ax.set(
    xlabel="$x$",
    ylabel="$y$",
    title="Функция $f(x) = x^3$ и её производные"
)
ax.grid(True, ls=":", c="k")
# Отобразим легенду - по умолчанию будет выбрано наилучшее расположение легенды
ax.legend()

# %% [markdown]
# Измения параметров линий графиков будут отражаться и в легенде. Сделаем основной график потолще, первую производную - пунктирной, вторую - полупрозрачной.

# %%
fig, ax = plt.subplots()
ax.plot(x, y, label="Функция $f(x)$", lw=3)
ax.plot(x, y_der, label="Производная $f'(x)$", ls="--")
ax.plot(x, y_der2, label="Производная $f''(x)$", alpha=0.5)
ax.set(
    xlabel="$x$",
    ylabel="$y$",
    title="Функция $f(x) = x^3$ и её производные"
)
ax.grid(True, ls=":", c="k")
ax.legend()

# %% [markdown]
# Как видите, `matplotlib` автоматически назначает цвета графикам. Цвета можно назначать и вручную. Когда это полезно? Рассмотрим такой случай.
#
# Представьте, что вы оформляете отчёт по какой-то своей большой работе. Вы помещаете туда построенный цветные графики.
# Но у вас не оказалось цветного принтера, а печать цветного отчёта со множеством картинок и графиков в копирке может влететь в копеечку. Печать чёрно-белого варианта работы может привести к такому результату:

# %%
fig, ax = plt.subplots()
ax.plot(x, y, label="Функция $f(x)$", c="k")
ax.plot(x, y_der, label="Производная $f'(x)$", c="k", alpha=0.7)
ax.plot(x, y_der2, label="Производная $f''(x)$", c="k", alpha=0.5)
ax.set(
    xlabel="$x$",
    ylabel="$y$",
    title="Функция $f(x) = x^3$ и её производные"
)
ax.grid(True, ls=":", c="k")
ax.legend()

# %% [markdown]
# Различие между графиками размыто.
# Различить графики можно по стилю линий или их толщине. Автоматически `matplotlib` ничего со стилем и толщиной линий не делает.
#
# Рекомендация следующая. Если вы планируете печать или публикацию своей работы в оттенках серого, то стройте все графики в чёрном цвете, разделяя их стилями и/или толщинами линий, например, так:

# %%
fig, ax = plt.subplots()
ax.plot(x, y, label="Функция $f(x)$", c="k")
ax.plot(x, y_der, label="Производная $f'(x)$", c="k", ls="--")
ax.plot(x, y_der2, label="Производная $f''(x)$", c="k", ls="-.")
ax.set(
    xlabel="$x$",
    ylabel="$y$",
    title="Функция $f(x) = x^3$ и её производные"
)
ax.grid(True, ls=":", c="k")
ax.legend()

# %% [markdown]
# ## Стили графиков
#
# В `matplotlib` имеется возможность настройки стилей графиков. Делается это, как вариантом, построением графиков в определённом стилевом контексте `plt.style.context(<style_name>)` с использованием оператора `with`.
#
# Список готовых стилей можно найти [здесь](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html).
#
# Построим график в стиле *bmh*:

# %%
with plt.style.context("bmh"):
    fig, ax = plt.subplots()
    ax.plot(x, y, label="Функция $f(x)$")
    ax.plot(x, y_der, label="Производная $f'(x)$")
    ax.plot(x, y_der2, label="Производная $f''(x)$")
    ax.set(
        xlabel="$x$",
        ylabel="$y$",
        title="Функция $f(x) = x^3$ и её производные"
    )
    ax.legend()

# %% [markdown]
# Стиль помимо прочего определяет собственные последовательности цветов линий, фона, сетки, легенды, шрифтов и т.д.
#
# Те же графики на тёмном фоне (полезно для презентаций в тёмных тонах или при публикациях на сайтах с тёмным окружением):

# %%
with plt.style.context("dark_background"):
    fig, ax = plt.subplots()
    ax.plot(x, y, label="Функция $f(x)$")
    ax.plot(x, y_der, label="Производная $f'(x)$")
    ax.plot(x, y_der2, label="Производная $f''(x)$")
    ax.set(
        xlabel="$x$",
        ylabel="$y$",
        title="Функция $f(x) = x^3$ и её производные"
    )
    ax.legend()

# %% [markdown]
# Для построения графиков для публикаций в оттенках серого вместо ручного переопределения цветов линий полезно использовать контекст *grayscale*, но при этом помнить о сложности различия оттенков и преимущественном различии графиков по стилю и/или толщине линий:

# %%
with plt.style.context("grayscale"):
    fig, ax = plt.subplots()
    ax.plot(x, y, label="Функция $f(x)$")
    ax.plot(x, y_der, label="Производная $f'(x)$", ls="--")
    ax.plot(x, y_der2, label="Производная $f''(x)$", ls=":")
    ax.set(
        xlabel="$x$",
        ylabel="$y$",
        title="Функция $f(x) = x^3$ и её производные"
    )
    ax.legend()

# %% [markdown]
# При стиле *seaborn-poster* будет построен большой график, качество которого позволяет распечатать его в высоком разрешении на большом формате, например, для постера:

# %%
with plt.style.context("seaborn-poster"):
    fig, ax = plt.subplots()
    ax.plot(x, y, label="Функция $f(x)$")
    ax.plot(x, y_der, label="Производная $f'(x)$")
    ax.plot(x, y_der2, label="Производная $f''(x)$")
    ax.set(
        xlabel="$x$",
        ylabel="$y$",
        title="Функция $f(x) = x^3$ и её производные"
    )
    ax.legend()

# %% [markdown]
# ### Создание собственного стиля графиков
#
# Рассмотрим, как можно настроить свой собственный стиль графиков.
#
# Настройка стиля производится через изменение словаря [`rcParams`](https://matplotlib.org/stable/tutorials/introductory/customizing.html), являющегося глобальной переменной библиотеки `matplotlib`.
#
# Основные требования к нашему стилю следующие:
#
# * семейство шрифта - serif;
# * размер шрифта - 12...14pt;
# * использование $\LaTeX$'а для отображения формул;
# * цвет линий по умолчанию - чёрный;
# * сетка - точечная серая.
#
# Чтобы не создавать словарь с нуля, будем отталкиваться от словаря стиля по умолчанию. Вот настройка нашего стиля:

# %%
# Имортируем саму библиотеку. Именно в ней лежит rcParams
from cycler import cycler
import matplotlib as mpl

# Копируем настройки по умолчанию
custom_style = mpl.rcParams.copy()
# Изменяем настройки
# * Рисунок
custom_style["figure.dpi"] = 120
# * Линии
#   - цвет линий (всех)
custom_style["axes.prop_cycle"] = (
    cycler(color=["k"]*4) +
    cycler(ls=["-", "--", ":", "-."])
)
# * Шрифт
#   - семейство
custom_style["font.family"] = "serif"
#   - размер
custom_style["font.size"] = 12
#   - формулы
custom_style["mathtext.fontset"] = "cm"
# * Оси
custom_style["axes.linewidth"] = 1.3
# * Засечки
#   - ось x
custom_style["xtick.minor.visible"] = True
custom_style["xtick.direction"] = "in"
custom_style["xtick.major.size"] = 4
#   - ось y
custom_style["ytick.minor.visible"] = True
custom_style["ytick.direction"] = "in"
custom_style["ytick.major.size"] = 4
# * Сетка
custom_style["axes.grid"] = True
custom_style["grid.linestyle"] = ":"
custom_style["grid.color"] = "gray"
# * Легенда
custom_style["legend.edgecolor"] = "black"
custom_style["legend.framealpha"] = 1
custom_style["legend.fontsize"] = "smaller"

# %% [markdown]
# Теперь у нас есть собственные настройки. Мы можем хранить их как глобальную переменную нашей программы и в нужный момент построить в этом стиле любой график вот так:

# %%
with plt.rc_context(custom_style):
    fig, ax = plt.subplots()
    ax.plot(x, y, label="$y = x^3$")
    ax.plot(x, y_der, label="$y' = 3 x^2$")
    ax.plot(x, y_der2, label="$y'' = 6 x$")
    ax.set(
        xlabel="$x$",
        ylabel="$y$, $y'$, $y''$",
        title="Пример собственного стиля"
    )
    ax.legend()

# %% [markdown]
# Подобный график не стыдно показать людям.

# %% [markdown]
# ## axline, axvline, axhline
#
# Методы `axline(...)`, `axvline(...)` и `axhline(...)` класса `plt.axis` предназначены для изображения бесконечных наклонных, вертикальных и горизонтальных прямых соответственно. *Бесконечность* в данном случае означает, что прямые проходят (по умолчанию) через всё поле построения графика, в т.ч. после масштабирования последнего.
#
# Рассмотрим график гиперболы
#
# $$f(x) = \cfrac{1}{x - 2} - 3.$$

# %%
def hyperbola(x):
    return 1 / (x - 2) - 3

xh = np.linspace(2.1, 12, 301)
yh = hyperbola(xh)

# %% [markdown]
# С помощью `axvline` и `axhline` мы можем показать соответственно вертикальную $x = 2$ и горизонтальную $y = -3$ асимптоты:

# %%
fig, ax = plt.subplots()
ax.plot(xh, yh)
ax.axvline(2, c="r", alpha=0.5)
ax.axhline(-3, c="b", alpha=0.5)
ax.set(xlabel="$x$", ylabel=r"$f(x) = -3 + \frac{1}{x - 2}$")
ax.grid()

# %% [markdown]
# Известно, что для данной гиперболы значение производной
#
# $$f'(x) = -\cfrac{1}{(x - 2)^2}$$
#
# в точке $x_0 = 3$ равно $-1$ (т.е. тангенс угла наклона касательной прямой в этой точке $k = -1$). Значение самой функции $f(x_0) = -2$. Используя эти данные, можно построить касательную к функции $f(x)$ в рассмотренной точке $x_0$.
#
# Уравнение касательной $f_{tan}(x) = k x + b$ получается элементарно:
# тангенс наклона известен ($k = -1$),
# смещение прямой
#
# $$b = f(x_0) - k x_0 = -2 - (-1 \cdot 3) = 1.$$
#
# Тогда уравнение касательной имеет вид
#
# $$f_{tan}(x) = 1 - x.$$
#
# Эта прямая пройдёт через две точки: $(3, -2)$ и $(2, -1 )$.
#
# Касательная по двум точкам строится методом `plt.axis.axline(...)`:

# %%
fig, ax = plt.subplots()
ax.plot(xh, yh)
ax.axvline(2, c="r", alpha=0.5)
ax.axhline(-3, c="b", alpha=0.5)

ax.axline(
    (3, -2),
    (2, -1),
    c="g",
    alpha=0.5
)

ax.set(xlabel="$x$", ylabel=r"$f(x) = -3 + \frac{1}{x - 2}$")
ax.grid()

# %% [markdown]
# Или в собственном стиле с добавлением легенды и одинаковым масштабом по осям:

# %%
with plt.rc_context(custom_style):
    fig, ax = plt.subplots()
    ax.plot(xh, yh, lw=2, label="Гипербола")
    ax.axvline(
        2,
        c="r",
        alpha=0.5,
        label="Вертикальная асимптота"
    )
    ax.axhline(
        -3,
        c="b",
        alpha=0.5,
        label="Горизонтальная асимптота"
    )
    ax.axline(
        (3, -2),
        (2, -1),
        c="g",
        alpha=0.5,
        label="Касательная"
    )
    ax.set(
        xlabel="$x$",
        ylabel=r"$f(x) = -3 + \frac{1}{x - 2}$",
        aspect="equal"
    )
    ax.legend()

# %% [markdown]
# ## Несколько осей на одном поле
#
# Иными словами сейчас рассмотрим, как в одном окне построить несколько графиков. Для этого сформулируем новую задачу.
#
# Пусть задана функция движения материальной точки вида
#
# $$x(t) = t^2 + t \sin{t} + \cfrac{1}{t + 1}.$$
#
# Функция скорости соответственно имеет вид
#
# $$v(t) = \dot{x} = 2t + \sin{t} + t \cos{t} - \cfrac{1}{(t + 1)^2}.$$
#
# Требуется построить графики этих функций один под другим.
#
# Сформируем данные для визуализации:

# %%
def fx(t):
    return t**2 + t*np.sin(t) + 1/(t + 1)

def fv(t):
    return 2*t + np.sin(t) + t*np.cos(t) - 1/(t + 1)**2

t = np.linspace(0, 3, 101)
x, v = fx(t), fv(t)

# %% [markdown]
# Подробнее рассмотрим метод `plt.sublots`. Как раз с его помощью можно решить поставленную задачу:

# %%
fig, (ax_top, ax_bottom) = plt.subplots(nrows=2)

# %% [markdown]
# Теперь у нас есть как бы 2 рабочих поля для построения графиков - верхнее и нижнее.
# Объекты `ax_top` и `ax_bottom` "работают" точно так же, как рассмотренные выше бъекты `ax` - они такие же объекты класса `plt.axis`.

# %%
fig, (ax_top, ax_bottom) = plt.subplots(nrows=2)
ax_top.plot(t, x)
ax_bottom.plot(t, v)

# %% [markdown]
# Подпишем оси:

# %%
fig, (ax_top, ax_bottom) = plt.subplots(nrows=2)

ax_top.plot(t, x)
ax_top.set(xlabel="$t$, с", ylabel="$x$, м")

ax_bottom.plot(t, v)
ax_bottom.set(xlabel="$t$, с", ylabel="$v$, м/с")
# Out:
# [Text(0.5, 0, '$t$, с'), Text(0, 0.5, '$v$, м/с')]

# %% [markdown]
# Заметили, что подпись оси *x* на верхнем графике перекрыта нижним графиком?
#
# С этим можно справиться либо изменением размера фигуры, либо (более хорошее решение в данном случае) назначением общих осей.
# Видно, что данные на осях *x* обоих графиков одинаковы и в физическом, и в численном отношении.
#
# Сделать горизонтальные оси можно, передав в метод `plt.sublots(...)` аргумент `sharex=True` (общая ось *y* - `sharey=True`).
# Также уберём метку `xlabel` в `ax_top.set(...)`.

# %%
fig, (ax_top, ax_bottom) = plt.subplots(nrows=2, sharex=True)

ax_top.plot(t, x)
ax_top.set(ylabel="$x$, м")

ax_bottom.plot(t, v)
ax_bottom.set(xlabel="$t$, с", ylabel="$v$, м/с")
# Out:
# [Text(0.5, 0, '$t$, с'), Text(0, 0.5, '$v$, м/с')]

# %% [markdown]
# Теперь графики выглядят более органично.
#
# И мы всё ещё можем использовать стилевой контекст. Заодно добавим названия (title) каждого графика:

# %%
with plt.rc_context(custom_style):
    fig, (ax_top, ax_bottom) = plt.subplots(nrows=2, sharex=True)

    ax_top.plot(t, x)
    ax_top.set(
        ylabel="$x$, м",
        title="Координата точки"
    )

    ax_bottom.plot(t, v)
    ax_bottom.set(
        xlabel="$t$, с",
        ylabel="$v$, м/с",
        title="Скорость точки"
    )
